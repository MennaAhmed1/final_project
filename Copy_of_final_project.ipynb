# %% [markdown]
# <a href="https://colab.research.google.com/github/MennaAhmed1/final_project/blob/main/Copy_of_final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/covid19.csv')
df.head()
# Out:
#    Unnamed: 0 Country,Other  TotalCases NewCases TotalDeaths
# 0           0           USA  29,383,324  +12,619    529,515
# 1           1         India  11,156,250  +16,927    157,471
# 2           2        Brazil  10,647,845      NaN    257,562
# 3           3        Russia   4,278,750  +10,535     87,348
# 4           4            UK   4,188,400      NaN    123,296

# %%
#removing incorrect data (data with no countries)
df2=df.drop([221,222,223,224,225,226,227,228],axis=0)

#replacing null values with 0
df2=df2.fillna(0)

# %%
#set 0 in all TotalDeaths that cannot be replaced with fillna
for i in range (220):
  if df2['TotalDeaths'][i]==' ':
    df2['TotalDeaths'][i]=0
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      Unnamed: 0     Country,Other  TotalCases NewCases TotalDeaths
# 0             0               USA  29,383,324  +12,619    529,515
# 1             1             India  11,156,250  +16,927    157,471
# 2             2            Brazil  10,647,845        0    257,562
# 3             3            Russia   4,278,750  +10,535     87,348
# 4             4                UK   4,188,400        0    123,296
# ..          ...               ...         ...      ...         ...
# 216         216  Marshall Islands           4        0           0
# 217         217             Samoa           3        0           0
# ...

# %%
#transforming TotalDeath into float
df2['TotalDeaths']=df2['TotalDeaths'].astype('f')
df2.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d7e6b5837d22> in <module>
#       1 #transforming TotalDeath into float
# ----> 2 df2['TotalDeaths']=df2['TotalDeaths'].astype('f')
#       3 df2.info()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
#saving the new spreadsheet
df2.to_csv('/content/covid19_new.csv')

# %%
df2.plot(kind='line')

# %%
df2.plot(kind='bar',,x='Country,Other',y='TotalCases',xlabel='country',ylabel='TotalCases')

# %%
import seaborn as sns
a = sns.barplot(data = df2[0:10],x="Country,Other", y="TotalCases")
a.tick_params(axis="x" , rotation=90)

# %%
import seaborn as sns
a = sns.barplot(data = df2[0:10],x="Country,Other", y="NewCases")
a.tick_params(axis="x" , rotation=90)

# %%
import seaborn as sns
a = sns.barplot(data = df2[0:10],x="Country,Other", y="TotalDeaths")
a.tick_params(axis="x" , rotation=90)

# %%
df2.plot(kind='line',x='Country,Other',y='TotalDeaths',xlabel='country',ylabel='TotalDeath')

# %%
df2.plot(kind='line',x='Country,Other',y='TotalCases',xlabel='country',ylabel='TotalCases')

# %%
df2.plot(kind='line',x='Country,Other',y='NewCases',xlabel='country',ylabel='NewCases')
